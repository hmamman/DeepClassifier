# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, LSTM, GRU, Bidirectional, Dense, Dropout, BatchNormalization, Concatenate, Flatten
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score, roc_auc_score, accuracy_score, f1_score
from imblearn.over_sampling import SMOTE
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('Datasets/pima.csv')
# df.drop('Unnamed: 0', axis=1, inplace=True)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# Load data
# data = pd.read_csv('datasets/pima/pima.csv')
X = df.drop('Outcome', axis=1)
y = df['Outcome']
# Encode target variable
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)  # Positive -> 1, Negative -> 0

# Handle missing values using SimpleImputer
imputer = SimpleImputer(strategy='mean')
X = imputer.fit_transform(X)

# Normalize numerical features
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
smote = SMOTE(random_state=42)
X, y = smote.fit_resample(X, y)
X_smote, y_smote = X, y

# %%
# Split data into training and testing sets (avoid scaling entire data)
X_train, X_test, y_train, y_test = train_test_split(X_smote, y_smote, test_size=0.2, random_state=32)

# %%
# Reshape for LSTM
X_train_lstm = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test_lstm = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
X_lstm = np.reshape(X, (X.shape[0], X.shape[1], 1))

# %%
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, LSTM, GRU, Bidirectional, Dense, Dropout, BatchNormalization, Concatenate

# Assuming your input data is in the format (samples, features)
# Define the inputs
inputs = Input(shape=(X_lstm.shape[1], 1))

# Dense layers
x = Dense(128, activation='relu')(inputs)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)

# Recurrent layers
x_lstm = Bidirectional(LSTM(64, return_sequences=True))(x)
x_gru = Bidirectional(GRU(64, return_sequences=True))(x)

# Concatenate LSTM and GRU outputs
x = Concatenate()([x_lstm, x_gru])
x = Flatten()(x)

# Dense layers
x = Dense(128, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)
x = Dense(64, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)

# Output layer
outputs = Dense(1, activation='sigmoid')(x)

# Define the model
model = Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=100)
# Train the model
history = model.fit(X_lstm, y, epochs=2000, batch_size=32, validation_split=0.2, callbacks=[early_stopping])

# Evaluate the model
loss, accuracy = model.evaluate(X_lstm, y)
print(f'Test Loss: {loss:.4f}')
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9114 - loss: 0.5060 - val_accuracy: 0.9150 - val_loss: 0.5206
# Epoch 2/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9271 - loss: 0.2371 - val_accuracy: 0.8500 - val_loss: 0.4637
# Epoch 3/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9582 - loss: 0.1314 - val_accuracy: 0.9550 - val_loss: 0.2189
# Epoch 4/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9355 - loss: 0.1837 - val_accuracy: 0.9500 - val_loss: 0.1675
# Epoch 5/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9364 - loss: 0.1778 - val_accuracy: 0.9500 - val_loss: 0.1656
# Epoch 6/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9513 - loss: 0.1199 - val_accuracy: 0.8750 - val_loss: 0.3001
# Epoch 7/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9467 - loss: 0.1474 - val_accuracy: 0.9800 - val_loss: 0.0991
# Epoch 8/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9433 - loss: 0.1604 - val_accuracy: 0.9300 - val_loss: 0.8813
# Epoch 9/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9476 - loss: 0.1187 - val_accuracy: 0.9850 - val_loss: 0.0864
# Epoch 10/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9604 - loss: 0.1165 - val_accuracy: 0.9850 - val_loss: 0.0817
# Epoch 11/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9624 - loss: 0.0986 - val_accuracy: 0.9900 - val_loss: 0.0551
# Epoch 12/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9765 - loss: 0.0861 - val_accuracy: 0.9900 - val_loss: 0.0705
# Epoch 13/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9619 - loss: 0.1059 - val_accuracy: 0.9900 - val_loss: 0.0671
# Epoch 14/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9710 - loss: 0.0823 - val_accuracy: 0.9850 - val_loss: 0.0559
# Epoch 15/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9733 - loss: 0.0724 - val_accuracy: 0.9800 - val_loss: 0.0610
# Epoch 16/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9818 - loss: 0.0587 - val_accuracy: 0.9850 - val_loss: 0.0488
# Epoch 17/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9716 - loss: 0.0730 - val_accuracy: 0.9850 - val_loss: 0.0564
# Epoch 18/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9784 - loss: 0.0547 - val_accuracy: 0.9850 - val_loss: 0.0578
# Epoch 19/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9509 - loss: 0.1083 - val_accuracy: 0.9900 - val_loss: 0.0769
# Epoch 20/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9822 - loss: 0.0757 - val_accuracy: 0.9900 - val_loss: 0.0568
# Epoch 21/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9748 - loss: 0.0640 - val_accuracy: 0.9850 - val_loss: 0.0579
# Epoch 22/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9800 - loss: 0.0580 - val_accuracy: 0.9850 - val_loss: 0.0619
# Epoch 23/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9630 - loss: 0.1010 - val_accuracy: 0.9900 - val_loss: 0.0596
# Epoch 24/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9805 - loss: 0.0509 - val_accuracy: 0.9850 - val_loss: 0.0615
# Epoch 25/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9688 - loss: 0.0802 - val_accuracy: 0.9800 - val_loss: 0.0563
# Epoch 26/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9617 - loss: 0.0813 - val_accuracy: 0.9900 - val_loss: 0.0478
# Epoch 27/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9793 - loss: 0.0524 - val_accuracy: 0.9900 - val_loss: 0.0326
# Epoch 28/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9546 - loss: 0.0845 - val_accuracy: 0.9900 - val_loss: 0.0597
# Epoch 29/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9813 - loss: 0.0544 - val_accuracy: 0.9800 - val_loss: 0.0595
# Epoch 30/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9655 - loss: 0.0755 - val_accuracy: 0.9850 - val_loss: 0.0613
# Epoch 31/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9900 - loss: 0.0364 - val_accuracy: 0.9850 - val_loss: 0.0511
# Epoch 32/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9694 - loss: 0.1001 - val_accuracy: 0.9900 - val_loss: 0.0255
# Epoch 33/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9868 - loss: 0.0403 - val_accuracy: 0.9850 - val_loss: 0.0428
# Epoch 34/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9704 - loss: 0.0754 - val_accuracy: 0.9800 - val_loss: 0.0813
# Epoch 35/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9728 - loss: 0.0783 - val_accuracy: 0.9900 - val_loss: 0.0493
# Epoch 36/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9629 - loss: 0.1052 - val_accuracy: 0.9800 - val_loss: 0.0880
# Epoch 37/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9741 - loss: 0.0790 - val_accuracy: 0.9900 - val_loss: 0.0490
# Epoch 38/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9861 - loss: 0.0648 - val_accuracy: 0.9850 - val_loss: 0.0445
# Epoch 39/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9774 - loss: 0.0911 - val_accuracy: 0.9800 - val_loss: 0.0855
# Epoch 40/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9881 - loss: 0.0398 - val_accuracy: 0.9850 - val_loss: 0.0712
# Epoch 41/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9780 - loss: 0.0472 - val_accuracy: 0.9900 - val_loss: 0.0591
# Epoch 42/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9759 - loss: 0.0771 - val_accuracy: 0.9850 - val_loss: 0.0621
# Epoch 43/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9796 - loss: 0.0555 - val_accuracy: 0.9750 - val_loss: 0.0687
# Epoch 44/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9866 - loss: 0.0460 - val_accuracy: 0.9850 - val_loss: 0.0432
# Epoch 45/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9786 - loss: 0.0637 - val_accuracy: 0.9900 - val_loss: 0.0379
# Epoch 46/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9880 - loss: 0.0350 - val_accuracy: 0.9900 - val_loss: 0.0464
# Epoch 47/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9760 - loss: 0.0560 - val_accuracy: 0.9850 - val_loss: 0.0666
# Epoch 48/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9847 - loss: 0.0479 - val_accuracy: 0.9900 - val_loss: 0.0531
# Epoch 49/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9759 - loss: 0.0708 - val_accuracy: 0.9850 - val_loss: 0.0803
# Epoch 50/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9891 - loss: 0.0391 - val_accuracy: 0.9800 - val_loss: 0.0740
# Epoch 51/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9792 - loss: 0.0487 - val_accuracy: 0.9800 - val_loss: 0.0775
# Epoch 52/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9801 - loss: 0.0788 - val_accuracy: 0.9850 - val_loss: 0.0761
# Epoch 53/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9819 - loss: 0.0528 - val_accuracy: 0.9850 - val_loss: 0.0288
# Epoch 54/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9773 - loss: 0.0534 - val_accuracy: 0.9900 - val_loss: 0.0546
# Epoch 55/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9910 - loss: 0.0385 - val_accuracy: 0.9850 - val_loss: 0.0639
# Epoch 56/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9857 - loss: 0.0367 - val_accuracy: 0.9750 - val_loss: 0.0685
# Epoch 57/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9880 - loss: 0.0448 - val_accuracy: 0.9800 - val_loss: 0.0803
# Epoch 58/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9817 - loss: 0.0512 - val_accuracy: 0.9750 - val_loss: 0.0816
# Epoch 59/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9927 - loss: 0.0312 - val_accuracy: 0.9900 - val_loss: 0.0670
# Epoch 60/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9770 - loss: 0.0649 - val_accuracy: 0.9900 - val_loss: 0.0459
# Epoch 61/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.0412 - val_accuracy: 0.9800 - val_loss: 0.0350
# Epoch 62/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9861 - loss: 0.0525 - val_accuracy: 0.9900 - val_loss: 0.0391
# Epoch 63/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9796 - loss: 0.0536 - val_accuracy: 0.9950 - val_loss: 0.0175
# Epoch 64/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9722 - loss: 0.0595 - val_accuracy: 0.9850 - val_loss: 0.0529
# Epoch 65/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9923 - loss: 0.0318 - val_accuracy: 0.9850 - val_loss: 0.0524
# Epoch 66/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9850 - loss: 0.0363 - val_accuracy: 0.9900 - val_loss: 0.0489
# Epoch 67/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9950 - loss: 0.0219 - val_accuracy: 0.9750 - val_loss: 0.0814
# Epoch 68/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9840 - loss: 0.0458 - val_accuracy: 0.9850 - val_loss: 0.0752
# Epoch 69/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9908 - loss: 0.0275 - val_accuracy: 0.9850 - val_loss: 0.0580
# Epoch 70/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9916 - loss: 0.0272 - val_accuracy: 0.9850 - val_loss: 0.0541
# Epoch 71/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9893 - loss: 0.0313 - val_accuracy: 0.9850 - val_loss: 0.0582
# Epoch 72/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9999 - loss: 0.0148 - val_accuracy: 0.9900 - val_loss: 0.0618
# Epoch 73/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9869 - loss: 0.0362 - val_accuracy: 0.9850 - val_loss: 0.0549
# Epoch 74/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9883 - loss: 0.0314 - val_accuracy: 0.9900 - val_loss: 0.0625
# Epoch 75/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9865 - loss: 0.0382 - val_accuracy: 0.9900 - val_loss: 0.0600
# Epoch 76/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9777 - loss: 0.0458 - val_accuracy: 0.9850 - val_loss: 0.0592
# Epoch 77/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9937 - loss: 0.0250 - val_accuracy: 0.9650 - val_loss: 0.1189
# Epoch 78/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9898 - loss: 0.0308 - val_accuracy: 0.9900 - val_loss: 0.0750
# Epoch 79/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9841 - loss: 0.0494 - val_accuracy: 0.9800 - val_loss: 0.0505
# Epoch 80/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9753 - loss: 0.0588 - val_accuracy: 0.9850 - val_loss: 0.0812
# Epoch 81/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9847 - loss: 0.0422 - val_accuracy: 0.9800 - val_loss: 0.0670
# Epoch 82/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9852 - loss: 0.0422 - val_accuracy: 0.9900 - val_loss: 0.0309
# Epoch 83/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9861 - loss: 0.0348 - val_accuracy: 0.9850 - val_loss: 0.0367
# Epoch 84/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9913 - loss: 0.0265 - val_accuracy: 0.9850 - val_loss: 0.0527
# Epoch 85/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9985 - loss: 0.0139 - val_accuracy: 0.9900 - val_loss: 0.0378
# Epoch 86/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9822 - loss: 0.0370 - val_accuracy: 0.9850 - val_loss: 0.0695
# Epoch 87/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9794 - loss: 0.0416 - val_accuracy: 0.9850 - val_loss: 0.0606
# Epoch 88/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9895 - loss: 0.0341 - val_accuracy: 0.9800 - val_loss: 0.0644
# Epoch 89/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.0218 - val_accuracy: 0.9800 - val_loss: 0.0973
# Epoch 90/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9713 - loss: 0.0578 - val_accuracy: 0.9800 - val_loss: 0.0673
# Epoch 91/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9908 - loss: 0.0249 - val_accuracy: 0.9900 - val_loss: 0.0613
# Epoch 92/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9908 - loss: 0.0279 - val_accuracy: 0.9900 - val_loss: 0.0313
# Epoch 93/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9926 - loss: 0.0292 - val_accuracy: 0.9850 - val_loss: 0.0380
# Epoch 94/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9898 - loss: 0.0244 - val_accuracy: 0.9900 - val_loss: 0.0753
# Epoch 95/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9827 - loss: 0.0349 - val_accuracy: 0.9950 - val_loss: 0.0162
# Epoch 96/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9903 - loss: 0.0332 - val_accuracy: 0.9850 - val_loss: 0.0398
# Epoch 97/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9837 - loss: 0.0365 - val_accuracy: 0.9850 - val_loss: 0.0637
# Epoch 98/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9885 - loss: 0.0431 - val_accuracy: 0.9850 - val_loss: 0.0667
# Epoch 99/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9880 - loss: 0.0368 - val_accuracy: 0.9900 - val_loss: 0.0960
# Epoch 100/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9800 - loss: 0.0793 - val_accuracy: 0.9850 - val_loss: 0.0691
# Epoch 101/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9906 - loss: 0.0465 - val_accuracy: 0.9850 - val_loss: 0.0746
# Epoch 102/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9881 - loss: 0.0317 - val_accuracy: 0.9900 - val_loss: 0.0782
# Epoch 103/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9891 - loss: 0.0317 - val_accuracy: 0.9900 - val_loss: 0.0589
# Epoch 104/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9907 - loss: 0.0447 - val_accuracy: 0.9850 - val_loss: 0.0712
# Epoch 105/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9763 - loss: 0.0522 - val_accuracy: 0.9850 - val_loss: 0.0781
# Epoch 106/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9829 - loss: 0.0471 - val_accuracy: 0.9850 - val_loss: 0.0439
# Epoch 107/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9828 - loss: 0.0348 - val_accuracy: 0.9850 - val_loss: 0.0805
# Epoch 108/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9867 - loss: 0.0289 - val_accuracy: 0.9850 - val_loss: 0.0811
# Epoch 109/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9932 - loss: 0.0203 - val_accuracy: 0.9800 - val_loss: 0.0965
# Epoch 110/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9911 - loss: 0.0253 - val_accuracy: 0.9850 - val_loss: 0.0817
# Epoch 111/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9901 - loss: 0.0338 - val_accuracy: 0.9700 - val_loss: 0.1106
# Epoch 112/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9940 - loss: 0.0312 - val_accuracy: 0.9700 - val_loss: 0.1130
# Epoch 113/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9883 - loss: 0.0319 - val_accuracy: 0.9650 - val_loss: 0.1078
# Epoch 114/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9832 - loss: 0.0376 - val_accuracy: 0.9900 - val_loss: 0.0565
# Epoch 115/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9829 - loss: 0.0396 - val_accuracy: 0.9900 - val_loss: 0.0601
# Epoch 116/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9868 - loss: 0.0341 - val_accuracy: 0.9850 - val_loss: 0.0846
# Epoch 117/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9781 - loss: 0.0742 - val_accuracy: 0.9900 - val_loss: 0.0450
# Epoch 118/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9970 - loss: 0.0200 - val_accuracy: 0.9800 - val_loss: 0.0699
# Epoch 119/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9922 - loss: 0.0225 - val_accuracy: 0.9900 - val_loss: 0.0497
# Epoch 120/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9757 - loss: 0.0790 - val_accuracy: 0.9900 - val_loss: 0.0430
# Epoch 121/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9946 - loss: 0.0224 - val_accuracy: 0.9900 - val_loss: 0.0184
# Epoch 122/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9843 - loss: 0.0443 - val_accuracy: 0.9900 - val_loss: 0.0703
# Epoch 123/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9958 - loss: 0.0452 - val_accuracy: 0.9900 - val_loss: 0.0472
# Epoch 124/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9824 - loss: 0.0323 - val_accuracy: 0.9800 - val_loss: 0.0520
# Epoch 125/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9920 - loss: 0.0282 - val_accuracy: 0.9900 - val_loss: 0.0694
# Epoch 126/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9764 - loss: 0.0451 - val_accuracy: 0.9800 - val_loss: 0.0371
# Epoch 127/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9946 - loss: 0.0216 - val_accuracy: 0.9850 - val_loss: 0.0468
# Epoch 128/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9974 - loss: 0.0119 - val_accuracy: 0.9900 - val_loss: 0.0736
# Epoch 129/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9908 - loss: 0.0328 - val_accuracy: 0.9900 - val_loss: 0.0844
# Epoch 130/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9775 - loss: 0.0525 - val_accuracy: 0.9750 - val_loss: 0.0599
# Epoch 131/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9951 - loss: 0.0187 - val_accuracy: 0.9850 - val_loss: 0.0805
# Epoch 132/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9839 - loss: 0.0437 - val_accuracy: 0.9850 - val_loss: 0.0627
# Epoch 133/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9948 - loss: 0.0233 - val_accuracy: 0.9750 - val_loss: 0.1222
# Epoch 134/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9887 - loss: 0.0328 - val_accuracy: 0.9550 - val_loss: 0.1485
# Epoch 135/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9969 - loss: 0.0175 - val_accuracy: 0.9900 - val_loss: 0.0553
# Epoch 136/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9906 - loss: 0.0299 - val_accuracy: 0.9850 - val_loss: 0.0772
# Epoch 137/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9833 - loss: 0.0388 - val_accuracy: 0.9800 - val_loss: 0.1016
# Epoch 138/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9902 - loss: 0.0268 - val_accuracy: 0.9900 - val_loss: 0.0994
# Epoch 139/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9843 - loss: 0.0642 - val_accuracy: 0.9850 - val_loss: 0.0601
# Epoch 140/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9981 - loss: 0.0145 - val_accuracy: 0.9900 - val_loss: 0.0664
# Epoch 141/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9934 - loss: 0.0260 - val_accuracy: 0.9900 - val_loss: 0.0421
# Epoch 142/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9991 - loss: 0.0088 - val_accuracy: 0.9900 - val_loss: 0.0544
# Epoch 143/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9986 - loss: 0.0133 - val_accuracy: 0.9900 - val_loss: 0.0546
# Epoch 144/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9951 - loss: 0.0213 - val_accuracy: 0.9900 - val_loss: 0.0853
# Epoch 145/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9894 - loss: 0.0352 - val_accuracy: 0.9900 - val_loss: 0.0650
# Epoch 146/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9966 - loss: 0.0143 - val_accuracy: 0.9900 - val_loss: 0.0550
# Epoch 147/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9902 - loss: 0.0212 - val_accuracy: 0.9900 - val_loss: 0.0726
# Epoch 148/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9988 - loss: 0.0089 - val_accuracy: 0.9900 - val_loss: 0.0695
# Epoch 149/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9901 - loss: 0.0329 - val_accuracy: 0.9800 - val_loss: 0.0425
# Epoch 150/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9784 - loss: 0.0624 - val_accuracy: 0.9750 - val_loss: 0.0895
# Epoch 151/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9845 - loss: 0.0429 - val_accuracy: 0.9900 - val_loss: 0.0373
# Epoch 152/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9878 - loss: 0.0328 - val_accuracy: 0.9900 - val_loss: 0.0399
# Epoch 153/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9810 - loss: 0.0481 - val_accuracy: 0.9850 - val_loss: 0.0958
# Epoch 154/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9871 - loss: 0.0476 - val_accuracy: 0.9600 - val_loss: 0.1266
# Epoch 155/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9760 - loss: 0.0875 - val_accuracy: 0.9900 - val_loss: 0.0543
# Epoch 156/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9936 - loss: 0.0216 - val_accuracy: 0.9900 - val_loss: 0.0747
# Epoch 157/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9862 - loss: 0.0342 - val_accuracy: 0.9850 - val_loss: 0.0898
# Epoch 158/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9857 - loss: 0.0525 - val_accuracy: 0.9850 - val_loss: 0.1071
# Epoch 159/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9960 - loss: 0.0157 - val_accuracy: 0.9850 - val_loss: 0.0927
# Epoch 160/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9940 - loss: 0.0182 - val_accuracy: 0.9800 - val_loss: 0.0603
# Epoch 161/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9844 - loss: 0.0351 - val_accuracy: 0.9800 - val_loss: 0.1087
# Epoch 162/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9929 - loss: 0.0206 - val_accuracy: 0.9900 - val_loss: 0.0685
# Epoch 163/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9869 - loss: 0.0436 - val_accuracy: 0.9850 - val_loss: 0.0700
# Epoch 164/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9993 - loss: 0.0125 - val_accuracy: 0.9800 - val_loss: 0.0879
# Epoch 165/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9785 - loss: 0.0696 - val_accuracy: 0.9900 - val_loss: 0.0648
# Epoch 166/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9947 - loss: 0.0233 - val_accuracy: 0.9850 - val_loss: 0.0391
# Epoch 167/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9865 - loss: 0.0389 - val_accuracy: 0.9800 - val_loss: 0.0730
# Epoch 168/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9940 - loss: 0.0200 - val_accuracy: 0.9900 - val_loss: 0.0625
# Epoch 169/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9893 - loss: 0.0350 - val_accuracy: 0.9900 - val_loss: 0.0575
# Epoch 170/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9918 - loss: 0.0302 - val_accuracy: 0.9850 - val_loss: 0.0546
# Epoch 171/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9936 - loss: 0.0132 - val_accuracy: 0.9850 - val_loss: 0.0537
# Epoch 172/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9859 - loss: 0.0289 - val_accuracy: 0.9700 - val_loss: 0.1090
# Epoch 173/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9973 - loss: 0.0124 - val_accuracy: 0.9700 - val_loss: 0.0805
# Epoch 174/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9879 - loss: 0.0291 - val_accuracy: 0.9700 - val_loss: 0.0876
# Epoch 175/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9772 - loss: 0.0588 - val_accuracy: 0.9900 - val_loss: 0.0608
# Epoch 176/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9895 - loss: 0.0223 - val_accuracy: 0.9900 - val_loss: 0.0375
# Epoch 177/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9875 - loss: 0.0358 - val_accuracy: 0.9700 - val_loss: 0.1202
# Epoch 178/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9914 - loss: 0.0207 - val_accuracy: 0.9900 - val_loss: 0.0450
# Epoch 179/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9869 - loss: 0.0322 - val_accuracy: 0.9850 - val_loss: 0.0362
# Epoch 180/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9865 - loss: 0.0394 - val_accuracy: 0.9800 - val_loss: 0.1043
# Epoch 181/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9981 - loss: 0.0155 - val_accuracy: 0.9750 - val_loss: 0.0958
# Epoch 182/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9968 - loss: 0.0171 - val_accuracy: 0.9900 - val_loss: 0.0455
# Epoch 183/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9892 - loss: 0.0428 - val_accuracy: 0.9900 - val_loss: 0.0511
# Epoch 184/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9851 - loss: 0.0391 - val_accuracy: 0.9900 - val_loss: 0.0286
# Epoch 185/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9879 - loss: 0.0283 - val_accuracy: 0.9900 - val_loss: 0.0419
# Epoch 186/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9980 - loss: 0.0153 - val_accuracy: 0.9900 - val_loss: 0.0604
# Epoch 187/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9842 - loss: 0.0354 - val_accuracy: 0.9900 - val_loss: 0.0369
# Epoch 188/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9949 - loss: 0.0296 - val_accuracy: 0.9900 - val_loss: 0.0540
# Epoch 189/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9927 - loss: 0.0275 - val_accuracy: 0.9900 - val_loss: 0.0424
# Epoch 190/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9967 - loss: 0.0118 - val_accuracy: 0.9900 - val_loss: 0.0382
# Epoch 191/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9869 - loss: 0.0237 - val_accuracy: 0.9900 - val_loss: 0.0587
# Epoch 192/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9972 - loss: 0.0125 - val_accuracy: 0.9900 - val_loss: 0.0791
# Epoch 193/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9918 - loss: 0.0446 - val_accuracy: 0.9850 - val_loss: 0.0669
# Epoch 194/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9943 - loss: 0.0291 - val_accuracy: 0.9850 - val_loss: 0.0676
# Epoch 195/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9907 - loss: 0.0257 - val_accuracy: 0.9900 - val_loss: 0.0705
# Epoch 196/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9929 - loss: 0.0220 - val_accuracy: 0.9900 - val_loss: 0.0748
# Epoch 197/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9948 - loss: 0.0152 - val_accuracy: 0.9900 - val_loss: 0.0334
# Epoch 198/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9893 - loss: 0.0418 - val_accuracy: 0.9900 - val_loss: 0.0542
# Epoch 199/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9954 - loss: 0.0117 - val_accuracy: 0.9900 - val_loss: 0.0628
# Epoch 200/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9965 - loss: 0.0105 - val_accuracy: 0.9900 - val_loss: 0.0780
# Epoch 201/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9979 - loss: 0.0135 - val_accuracy: 0.9900 - val_loss: 0.0763
# Epoch 202/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9895 - loss: 0.0435 - val_accuracy: 0.9850 - val_loss: 0.0888
# Epoch 203/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9965 - loss: 0.0120 - val_accuracy: 0.9900 - val_loss: 0.0807
# Epoch 204/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9964 - loss: 0.0150 - val_accuracy: 0.9750 - val_loss: 0.0592
# Epoch 205/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9901 - loss: 0.0340 - val_accuracy: 0.9900 - val_loss: 0.0587
# Epoch 206/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9880 - loss: 0.0259 - val_accuracy: 0.9800 - val_loss: 0.0714
# Epoch 207/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9936 - loss: 0.0185 - val_accuracy: 0.9900 - val_loss: 0.0496
# Epoch 208/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9917 - loss: 0.0198 - val_accuracy: 0.9750 - val_loss: 0.0614
# Epoch 209/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9987 - loss: 0.0084 - val_accuracy: 0.9900 - val_loss: 0.0309
# Epoch 210/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9968 - loss: 0.0177 - val_accuracy: 0.9900 - val_loss: 0.0456
# Epoch 211/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9979 - loss: 0.0147 - val_accuracy: 0.9900 - val_loss: 0.0590
# Epoch 212/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9937 - loss: 0.0331 - val_accuracy: 0.9850 - val_loss: 0.0712
# Epoch 213/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9976 - loss: 0.0165 - val_accuracy: 0.9850 - val_loss: 0.0620
# Epoch 214/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9837 - loss: 0.0320 - val_accuracy: 0.9800 - val_loss: 0.0651
# Epoch 215/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9792 - loss: 0.0373 - val_accuracy: 0.9700 - val_loss: 0.0995
# Epoch 216/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9856 - loss: 0.0371 - val_accuracy: 0.9850 - val_loss: 0.0298
# Epoch 217/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9878 - loss: 0.0417 - val_accuracy: 0.9900 - val_loss: 0.0573
# Epoch 218/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9933 - loss: 0.0221 - val_accuracy: 0.9900 - val_loss: 0.0438
# Epoch 219/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9948 - loss: 0.0140 - val_accuracy: 0.9850 - val_loss: 0.0916
# Epoch 220/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9940 - loss: 0.0144 - val_accuracy: 0.9850 - val_loss: 0.0893
# Epoch 221/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9830 - loss: 0.0419 - val_accuracy: 0.9900 - val_loss: 0.0505
# Epoch 222/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9972 - loss: 0.0125 - val_accuracy: 0.9900 - val_loss: 0.0709
# Epoch 223/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9867 - loss: 0.0279 - val_accuracy: 0.9750 - val_loss: 0.1489
# Epoch 224/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9901 - loss: 0.0209 - val_accuracy: 0.9850 - val_loss: 0.0716
# Epoch 225/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9889 - loss: 0.0272 - val_accuracy: 0.9750 - val_loss: 0.0910
# Epoch 226/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9903 - loss: 0.0540 - val_accuracy: 0.9900 - val_loss: 0.0933
# Epoch 227/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9864 - loss: 0.0498 - val_accuracy: 0.9550 - val_loss: 0.1980
# Epoch 228/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9924 - loss: 0.0191 - val_accuracy: 0.9900 - val_loss: 0.1231
# Epoch 229/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9920 - loss: 0.0315 - val_accuracy: 0.9900 - val_loss: 0.0475
# Epoch 230/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9963 - loss: 0.0193 - val_accuracy: 0.9900 - val_loss: 0.0779
# Epoch 231/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9887 - loss: 0.0688 - val_accuracy: 0.9900 - val_loss: 0.0520
# Epoch 232/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9923 - loss: 0.0233 - val_accuracy: 0.9900 - val_loss: 0.0319
# Epoch 233/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9844 - loss: 0.0457 - val_accuracy: 0.9750 - val_loss: 0.0683
# Epoch 234/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9948 - loss: 0.0241 - val_accuracy: 0.9850 - val_loss: 0.0672
# Epoch 235/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9932 - loss: 0.0206 - val_accuracy: 0.9900 - val_loss: 0.0413
# Epoch 236/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9955 - loss: 0.0208 - val_accuracy: 0.9800 - val_loss: 0.0758
# Epoch 237/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9930 - loss: 0.0223 - val_accuracy: 0.9900 - val_loss: 0.0743
# Epoch 238/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9879 - loss: 0.0320 - val_accuracy: 0.9900 - val_loss: 0.0556
# Epoch 239/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9980 - loss: 0.0060 - val_accuracy: 0.9900 - val_loss: 0.0615
# Epoch 240/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9958 - loss: 0.0172 - val_accuracy: 0.9900 - val_loss: 0.0609
# Epoch 241/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9927 - loss: 0.0427 - val_accuracy: 0.9900 - val_loss: 0.0651
# Epoch 242/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9961 - loss: 0.0134 - val_accuracy: 0.9900 - val_loss: 0.0648
# Epoch 243/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9893 - loss: 0.0293 - val_accuracy: 0.9850 - val_loss: 0.0862
# Epoch 244/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9867 - loss: 0.0492 - val_accuracy: 0.9700 - val_loss: 0.0935
# Epoch 245/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9964 - loss: 0.0179 - val_accuracy: 0.9850 - val_loss: 0.0613
# Epoch 246/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9802 - loss: 0.0492 - val_accuracy: 0.9850 - val_loss: 0.0613
# Epoch 247/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9934 - loss: 0.0131 - val_accuracy: 0.9850 - val_loss: 0.0517
# Epoch 248/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9822 - loss: 0.0401 - val_accuracy: 0.9950 - val_loss: 0.0317
# Epoch 249/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9919 - loss: 0.0261 - val_accuracy: 0.9850 - val_loss: 0.0748
# Epoch 250/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9779 - loss: 0.0530 - val_accuracy: 0.9800 - val_loss: 0.0680
# Epoch 251/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9918 - loss: 0.0226 - val_accuracy: 0.9950 - val_loss: 0.0380
# Epoch 252/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9894 - loss: 0.0284 - val_accuracy: 0.9900 - val_loss: 0.0556
# Epoch 253/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9932 - loss: 0.0174 - val_accuracy: 0.9900 - val_loss: 0.0376
# Epoch 254/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9799 - loss: 0.0771 - val_accuracy: 0.9950 - val_loss: 0.0268
# Epoch 255/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9924 - loss: 0.0181 - val_accuracy: 0.9800 - val_loss: 0.0652
# Epoch 256/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9919 - loss: 0.0307 - val_accuracy: 0.9800 - val_loss: 0.0574
# Epoch 257/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9862 - loss: 0.0315 - val_accuracy: 0.9650 - val_loss: 0.0985
# Epoch 258/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9936 - loss: 0.0176 - val_accuracy: 0.9850 - val_loss: 0.0802
# Epoch 259/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9970 - loss: 0.0150 - val_accuracy: 0.9900 - val_loss: 0.0635
# Epoch 260/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9929 - loss: 0.0179 - val_accuracy: 0.9850 - val_loss: 0.0773
# Epoch 261/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9875 - loss: 0.0418 - val_accuracy: 0.9900 - val_loss: 0.0474
# Epoch 262/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9955 - loss: 0.0122 - val_accuracy: 0.9900 - val_loss: 0.0625
# Epoch 263/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9834 - loss: 0.0228 - val_accuracy: 0.9900 - val_loss: 0.0619
# Epoch 264/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9877 - loss: 0.0338 - val_accuracy: 0.9900 - val_loss: 0.0590
# Epoch 265/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9949 - loss: 0.0233 - val_accuracy: 0.9900 - val_loss: 0.0957
# Epoch 266/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9796 - loss: 0.0469 - val_accuracy: 0.9850 - val_loss: 0.0470
# Epoch 267/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9866 - loss: 0.0308 - val_accuracy: 0.9900 - val_loss: 0.0885
# Epoch 268/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9945 - loss: 0.0137 - val_accuracy: 0.9900 - val_loss: 0.0705
# Epoch 269/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9910 - loss: 0.0208 - val_accuracy: 0.9900 - val_loss: 0.0928
# Epoch 270/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9829 - loss: 0.0407 - val_accuracy: 0.9900 - val_loss: 0.0574
# Epoch 271/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9940 - loss: 0.0270 - val_accuracy: 0.9900 - val_loss: 0.0638
# Epoch 272/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9943 - loss: 0.0220 - val_accuracy: 0.9850 - val_loss: 0.0484
# Epoch 273/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9942 - loss: 0.0132 - val_accuracy: 0.9900 - val_loss: 0.0544
# Epoch 274/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9924 - loss: 0.0303 - val_accuracy: 0.9600 - val_loss: 0.1140
# Epoch 275/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9968 - loss: 0.0137 - val_accuracy: 0.9850 - val_loss: 0.0830
# Epoch 276/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9929 - loss: 0.0157 - val_accuracy: 0.9900 - val_loss: 0.0681
# Epoch 277/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9977 - loss: 0.0102 - val_accuracy: 0.9900 - val_loss: 0.0514
# Epoch 278/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9928 - loss: 0.0155 - val_accuracy: 0.9900 - val_loss: 0.0568
# Epoch 279/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9886 - loss: 0.0268 - val_accuracy: 0.9850 - val_loss: 0.0952
# Epoch 280/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9900 - loss: 0.0658 - val_accuracy: 0.9900 - val_loss: 0.0960
# Epoch 281/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9932 - loss: 0.0121 - val_accuracy: 0.9800 - val_loss: 0.1144
# Epoch 282/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9910 - loss: 0.0547 - val_accuracy: 0.9800 - val_loss: 0.1024
# Epoch 283/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9943 - loss: 0.0214 - val_accuracy: 0.9900 - val_loss: 0.0327
# Epoch 284/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9914 - loss: 0.0278 - val_accuracy: 0.9900 - val_loss: 0.0716
# Epoch 285/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9939 - loss: 0.0131 - val_accuracy: 0.9900 - val_loss: 0.0762
# Epoch 286/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9899 - loss: 0.0245 - val_accuracy: 0.9750 - val_loss: 0.0912
# Epoch 287/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9950 - loss: 0.0188 - val_accuracy: 0.9850 - val_loss: 0.0519
# Epoch 288/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9968 - loss: 0.0126 - val_accuracy: 0.9900 - val_loss: 0.0640
# Epoch 289/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9972 - loss: 0.0101 - val_accuracy: 0.9850 - val_loss: 0.0491
# Epoch 290/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9912 - loss: 0.0353 - val_accuracy: 0.9850 - val_loss: 0.0773
# Epoch 291/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9968 - loss: 0.0147 - val_accuracy: 0.9850 - val_loss: 0.0780
# Epoch 292/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9959 - loss: 0.0122 - val_accuracy: 0.9900 - val_loss: 0.0745
# Epoch 293/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9969 - loss: 0.0189 - val_accuracy: 0.9900 - val_loss: 0.0967
# Epoch 294/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9887 - loss: 0.0236 - val_accuracy: 0.9900 - val_loss: 0.0782
# Epoch 295/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9910 - loss: 0.0188 - val_accuracy: 0.9850 - val_loss: 0.0484
# Epoch 296/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9988 - loss: 0.0055 - val_accuracy: 0.9900 - val_loss: 0.0431
# Epoch 297/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9941 - loss: 0.0117 - val_accuracy: 0.9900 - val_loss: 0.0644
# Epoch 298/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9952 - loss: 0.0124 - val_accuracy: 0.9800 - val_loss: 0.0794
# Epoch 299/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9954 - loss: 0.0125 - val_accuracy: 0.9900 - val_loss: 0.0412
# Epoch 300/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9881 - loss: 0.0237 - val_accuracy: 0.9750 - val_loss: 0.1381
# Epoch 301/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9879 - loss: 0.0373 - val_accuracy: 0.9700 - val_loss: 0.1364
# Epoch 302/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9899 - loss: 0.0278 - val_accuracy: 0.9800 - val_loss: 0.1148
# Epoch 303/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9907 - loss: 0.0485 - val_accuracy: 0.9850 - val_loss: 0.0960
# Epoch 304/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9946 - loss: 0.0199 - val_accuracy: 0.9850 - val_loss: 0.0258
# Epoch 305/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9871 - loss: 0.0378 - val_accuracy: 0.9900 - val_loss: 0.0456
# Epoch 306/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9912 - loss: 0.0327 - val_accuracy: 0.9750 - val_loss: 0.0915
# Epoch 307/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9929 - loss: 0.0197 - val_accuracy: 0.9750 - val_loss: 0.1006
# Epoch 308/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9825 - loss: 0.0331 - val_accuracy: 0.9750 - val_loss: 0.0924
# Epoch 309/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9967 - loss: 0.0209 - val_accuracy: 0.9900 - val_loss: 0.0353
# Epoch 310/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9962 - loss: 0.0171 - val_accuracy: 0.9900 - val_loss: 0.0630
# Epoch 311/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9931 - loss: 0.0359 - val_accuracy: 0.9900 - val_loss: 0.0567
# Epoch 312/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9863 - loss: 0.0302 - val_accuracy: 0.9850 - val_loss: 0.0488
# Epoch 313/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9921 - loss: 0.0237 - val_accuracy: 0.9800 - val_loss: 0.0584
# Epoch 314/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9760 - loss: 0.0697 - val_accuracy: 0.9800 - val_loss: 0.0556
# Epoch 315/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9931 - loss: 0.0277 - val_accuracy: 0.9850 - val_loss: 0.0629
# Epoch 316/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9839 - loss: 0.0417 - val_accuracy: 0.9900 - val_loss: 0.0357
# Epoch 317/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9836 - loss: 0.0512 - val_accuracy: 0.9900 - val_loss: 0.0438
# Epoch 318/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9947 - loss: 0.0263 - val_accuracy: 0.9800 - val_loss: 0.0322
# Epoch 319/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9931 - loss: 0.0243 - val_accuracy: 0.9750 - val_loss: 0.1162
# Epoch 320/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9902 - loss: 0.0351 - val_accuracy: 0.9800 - val_loss: 0.1598
# Epoch 321/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9963 - loss: 0.0115 - val_accuracy: 0.9800 - val_loss: 0.1231
# Epoch 322/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9953 - loss: 0.0144 - val_accuracy: 0.9800 - val_loss: 0.1551
# Epoch 323/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9914 - loss: 0.0215 - val_accuracy: 0.9800 - val_loss: 0.0928
# Epoch 324/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9923 - loss: 0.0241 - val_accuracy: 0.9800 - val_loss: 0.0856
# Epoch 325/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9926 - loss: 0.0243 - val_accuracy: 0.9800 - val_loss: 0.0853
# Epoch 326/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9929 - loss: 0.0234 - val_accuracy: 0.9800 - val_loss: 0.1035
# Epoch 327/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9916 - loss: 0.0344 - val_accuracy: 0.9800 - val_loss: 0.0933
# Epoch 328/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9943 - loss: 0.0184 - val_accuracy: 0.9850 - val_loss: 0.1033
# Epoch 329/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9913 - loss: 0.0142 - val_accuracy: 0.9850 - val_loss: 0.0895
# Epoch 330/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0212 - val_accuracy: 0.9850 - val_loss: 0.1025
# Epoch 331/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9957 - loss: 0.0255 - val_accuracy: 0.9850 - val_loss: 0.0743
# Epoch 332/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9880 - loss: 0.0414 - val_accuracy: 0.9800 - val_loss: 0.0864
# Epoch 333/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9868 - loss: 0.0233 - val_accuracy: 0.9850 - val_loss: 0.0453
# Epoch 334/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9911 - loss: 0.0185 - val_accuracy: 0.9850 - val_loss: 0.0212
# Epoch 335/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9978 - loss: 0.0087 - val_accuracy: 0.9900 - val_loss: 0.0190
# Epoch 336/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9937 - loss: 0.0180 - val_accuracy: 0.9900 - val_loss: 0.0603
# Epoch 337/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.0152 - val_accuracy: 0.9800 - val_loss: 0.0482
# Epoch 338/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9922 - loss: 0.0336 - val_accuracy: 0.9750 - val_loss: 0.1057
# Epoch 339/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9886 - loss: 0.0472 - val_accuracy: 0.9900 - val_loss: 0.0848
# Epoch 340/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9793 - loss: 0.0770 - val_accuracy: 0.9800 - val_loss: 0.1148
# Epoch 341/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9959 - loss: 0.0219 - val_accuracy: 0.9800 - val_loss: 0.0900
# Epoch 342/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9931 - loss: 0.0147 - val_accuracy: 0.9850 - val_loss: 0.0523
# Epoch 343/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9979 - loss: 0.0056 - val_accuracy: 0.9900 - val_loss: 0.0456
# Epoch 344/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0151 - val_accuracy: 0.9900 - val_loss: 0.0575
# Epoch 345/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9985 - loss: 0.0055 - val_accuracy: 0.9850 - val_loss: 0.0592
# Epoch 346/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9938 - loss: 0.0319 - val_accuracy: 0.9900 - val_loss: 0.0605
# Epoch 347/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9967 - loss: 0.0092 - val_accuracy: 0.9900 - val_loss: 0.0776
# Epoch 348/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9948 - loss: 0.0116 - val_accuracy: 0.9900 - val_loss: 0.0508
# Epoch 349/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9897 - loss: 0.0374 - val_accuracy: 0.9900 - val_loss: 0.0409
# Epoch 350/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9979 - loss: 0.0137 - val_accuracy: 0.9850 - val_loss: 0.0799
# Epoch 351/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9929 - loss: 0.0140 - val_accuracy: 0.9750 - val_loss: 0.0913
# Epoch 352/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9902 - loss: 0.0217 - val_accuracy: 0.9900 - val_loss: 0.0411
# Epoch 353/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9973 - loss: 0.0106 - val_accuracy: 0.9900 - val_loss: 0.0781
# Epoch 354/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9850 - val_loss: 0.0603
# Epoch 355/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9997 - loss: 0.0047 - val_accuracy: 0.9900 - val_loss: 0.0563
# Epoch 356/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9900 - val_loss: 0.0571
# Epoch 357/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9954 - loss: 0.0134 - val_accuracy: 0.9850 - val_loss: 0.0775
# Epoch 358/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9925 - loss: 0.0276 - val_accuracy: 0.9850 - val_loss: 0.0787
# Epoch 359/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9942 - loss: 0.0257 - val_accuracy: 0.9850 - val_loss: 0.0988
# Epoch 360/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9980 - loss: 0.0083 - val_accuracy: 0.9850 - val_loss: 0.0640
# Epoch 361/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9972 - loss: 0.0143 - val_accuracy: 0.9800 - val_loss: 0.0556
# Epoch 362/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9896 - loss: 0.0436 - val_accuracy: 0.9850 - val_loss: 0.0567
# Epoch 363/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9844 - loss: 0.0428 - val_accuracy: 0.9900 - val_loss: 0.0992
# Epoch 364/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9981 - loss: 0.0142 - val_accuracy: 0.9850 - val_loss: 0.0721
# Epoch 365/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9894 - loss: 0.0369 - val_accuracy: 0.9850 - val_loss: 0.0475
# Epoch 366/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9937 - loss: 0.0174 - val_accuracy: 0.9850 - val_loss: 0.0720
# Epoch 367/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9959 - loss: 0.0111 - val_accuracy: 0.9850 - val_loss: 0.0823
# Epoch 368/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9839 - loss: 0.0252 - val_accuracy: 0.9900 - val_loss: 0.1377
# Epoch 369/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9932 - loss: 0.0429 - val_accuracy: 0.9750 - val_loss: 0.1092
# Epoch 370/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9950 - loss: 0.0155 - val_accuracy: 0.9850 - val_loss: 0.0970
# Epoch 371/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9953 - loss: 0.0144 - val_accuracy: 0.9850 - val_loss: 0.0798
# Epoch 372/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9952 - loss: 0.0154 - val_accuracy: 0.9900 - val_loss: 0.0693
# Epoch 373/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9951 - loss: 0.0293 - val_accuracy: 0.9850 - val_loss: 0.0983
# Epoch 374/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9909 - loss: 0.0376 - val_accuracy: 0.9650 - val_loss: 0.1280
# Epoch 375/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9941 - loss: 0.0238 - val_accuracy: 0.9800 - val_loss: 0.0973
# Epoch 376/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9946 - loss: 0.0207 - val_accuracy: 0.9850 - val_loss: 0.0966
# Epoch 377/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9961 - loss: 0.0181 - val_accuracy: 0.9900 - val_loss: 0.0874
# Epoch 378/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9980 - loss: 0.0118 - val_accuracy: 0.9800 - val_loss: 0.1103
# Epoch 379/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9957 - loss: 0.0187 - val_accuracy: 0.9800 - val_loss: 0.0982
# Epoch 380/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9987 - loss: 0.0079 - val_accuracy: 0.9700 - val_loss: 0.1869
# Epoch 381/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9908 - loss: 0.0168 - val_accuracy: 0.9800 - val_loss: 0.0937
# Epoch 382/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9965 - loss: 0.0126 - val_accuracy: 0.9900 - val_loss: 0.0509
# Epoch 383/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0219 - val_accuracy: 0.9900 - val_loss: 0.0898
# Epoch 384/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9896 - loss: 0.0242 - val_accuracy: 0.9900 - val_loss: 0.0555
# Epoch 385/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9972 - loss: 0.0092 - val_accuracy: 0.9900 - val_loss: 0.0441
# Epoch 386/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9971 - loss: 0.0108 - val_accuracy: 0.9900 - val_loss: 0.0466
# Epoch 387/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9954 - loss: 0.0116 - val_accuracy: 0.9700 - val_loss: 0.1026
# Epoch 388/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9960 - loss: 0.0100 - val_accuracy: 0.9900 - val_loss: 0.1461
# Epoch 389/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9997 - loss: 0.0052 - val_accuracy: 0.9850 - val_loss: 0.1245
# Epoch 390/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9885 - loss: 0.0378 - val_accuracy: 0.9750 - val_loss: 0.1453
# Epoch 391/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9952 - loss: 0.0089 - val_accuracy: 0.9700 - val_loss: 0.1153
# Epoch 392/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9955 - loss: 0.0119 - val_accuracy: 0.9800 - val_loss: 0.0783
# Epoch 393/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9954 - loss: 0.0164 - val_accuracy: 0.9850 - val_loss: 0.1037
# Epoch 394/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9953 - loss: 0.0226 - val_accuracy: 0.9900 - val_loss: 0.0404
# Epoch 395/2000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9967 - loss: 0.0226 - val_accuracy: 0.9900 - val_loss: 0.0625
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9998 - loss: 0.0013
# Test Loss: 0.0128
# Test Accuracy: 0.9980

# %%
# Save the entire model to a file
model.save('Results/pima/bilstm_model.keras')
# Save only the model's weights to a file
model.save_weights('Results/pima/bilstm_model.weights.h5')
# Save only the model's architecture to a JSON file
model_json = model.to_json()
with open('Results/pima/bistlm_model_architecture.json', 'w') as json_file:
    json_file.write(model_json)

# Save X_test as a NumPy array
np.save('Results/pima/bilstm_X_test.npy', X_test_lstm)

# Save y_test as a NumPy array
np.save('Results/pima/bilstm_y_test.npy', y_test)

# Get the training and validation accuracy and loss values
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Save the accuracy and loss values as NumPy arrays
np.save('Results/pima/bilstm_train_acc.npy', train_acc)
np.save('Results/pima/bilstm_val_acc.npy', val_acc)
np.save('Results/pima/bilstm_train_loss.npy', train_loss)
np.save('Results/pima/bilstm_val_loss.npy', val_loss)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Make predictions on the test set
y_pred = model.predict(X_test) > 0.5
y_pred = y_pred.astype(int)

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title('Confusion Matrix', fontsize=12, fontweight='normal')
plt.xlabel('Predicted Label', fontsize=12, labelpad=10)
plt.ylabel('True Label', fontsize=12, labelpad=10)
plt.show()
# Set the title and labels
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 236ms/step

# %%
from sklearn.metrics import classification_report

# Generate the classification report
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83        94
#            1       0.86      0.82      0.84       106
#
#     accuracy                           0.83       200
#    macro avg       0.83      0.84      0.83       200
# weighted avg       0.84      0.83      0.84       200

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score

# Create a figure with subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Set background color and grid style for all subplots
fig.set_facecolor('white')
for ax in axes.flat:
    ax.grid(color='gray', linestyle='-', linewidth=0.5, alpha=0.5)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

# Plot accuracy
axes[0, 0].plot(history.history['accuracy'], linewidth=2, color='#1f77b4', label='Training set')
axes[0, 0].plot(history.history['val_accuracy'], linewidth=2, color='#ff7f0e', label='Testing set')
axes[0, 0].set_title('Model Accuracy', fontsize=12, fontweight='normal')
axes[0, 0].set_ylabel('Accuracy', fontsize=12)
axes[0, 0].set_xlabel('Epoch', fontsize=12)
axes[0, 0].legend(loc='lower right', fontsize=10)
axes[0, 0].tick_params(axis='both', which='major', labelsize=10)

# Plot loss
axes[0, 1].plot(history.history['loss'], linewidth=2, color='#1f77b4', label='Training set')
axes[0, 1].plot(history.history['val_loss'], linewidth=2, color='#ff7f0e', label='Testing set')
axes[0, 1].set_title('Model Loss', fontsize=12, fontweight='normal')
axes[0, 1].set_ylabel('Loss', fontsize=12)
axes[0, 1].set_xlabel('Epoch', fontsize=12)
axes[0, 1].legend(loc='upper right', fontsize=10)
axes[0, 1].tick_params(axis='both', which='major', labelsize=10)

# Compute the ROC curve and AUC score
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
axes[1, 0].plot(fpr, tpr, color='#ff7f0e', linewidth=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
axes[1, 0].plot([0, 1], [0, 1], color='#1f77b4', linewidth=2, linestyle='--', label='Random guess')
axes[1, 0].set_xlim([0.0, 1.0])
axes[1, 0].set_ylim([0.0, 1.05])
axes[1, 0].set_xlabel('False Positive Rate', fontsize=12)
axes[1, 0].set_ylabel('True Positive Rate', fontsize=12)
axes[1, 0].set_title('ROC Curve', fontsize=12, fontweight='normal')
axes[1, 0].tick_params(axis='both', which='major', labelsize=10)
axes[1, 0].legend(loc='lower right', fontsize=10)

# Compute Precision-Recall curve and average precision score
y_score = model.predict(X_test)
precision, recall, _ = precision_recall_curve(y_test, y_score)
ap = average_precision_score(y_test, y_score)

# Plot Precision-Recall curve
axes[1, 1].plot(recall, precision, color='#ff7f0e', linewidth=2, label=f'Precision-Recall curve (AP = {ap:.2f})')
axes[1, 1].set_xlabel('Recall', fontsize=12)
axes[1, 1].set_ylabel('Precision', fontsize=12)
axes[1, 1].set_title('Precision-Recall Curve', fontsize=12, fontweight='normal')
axes[1, 1].tick_params(axis='both', which='major', labelsize=10)
axes[1, 1].legend(loc="lower left", fontsize=10)

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

def pca_plot(test_x_scaled, test_y, test_y_pred, size=100, markersize=1):
    pca = PCA(n_components=2)
    x_pca = pca.fit_transform(test_x_scaled)

    true_np = np.hstack((x_pca, test_y.reshape(len(test_y), 1)))
    pred_np = np.hstack((x_pca, test_y_pred.reshape(len(test_y_pred), 1)))

    column_true = ['pc_0', 'pc_1', 'true']
    column_pred = ['pc_0', 'pc_1', 'pred']

    true_df = pd.DataFrame(data=true_np, columns=column_true)
    pred_df = pd.DataFrame(data=pred_np, columns=column_pred)

    true_df_0 = true_df[true_df['true'] == 0]
    true_df_1 = true_df[true_df['true'] == 1]
    true_x_0 = true_df_0.iloc[:, :-1].to_numpy()
    true_x_1 = true_df_1.iloc[:, :-1].to_numpy()

    pred_df_0 = pred_df[pred_df['pred'] == 0]
    pred_df_1 = pred_df[pred_df['pred'] == 1]
    pred_x_0 = pred_df_0.iloc[:, :-1].to_numpy()
    pred_x_1 = pred_df_1.iloc[:, :-1].to_numpy()

    join_df = true_df.join(pred_df['pred'], rsuffix='_pred')

    correct_df = join_df[join_df['true'] == join_df['pred']]
    wrong_df = join_df[join_df['true'] != join_df['pred']]

    correct_df_0 = correct_df[correct_df['true'] == 0]
    correct_df_1 = correct_df[correct_df['true'] == 1]
    correct_x_0 = correct_df_0.iloc[:, :-2].to_numpy()
    correct_x_1 = correct_df_1.iloc[:, :-2].to_numpy()

    fn_df = wrong_df[wrong_df['pred'] == 0]
    fp_df = wrong_df[wrong_df['pred'] == 1]
    fn_x = fn_df.iloc[:, :-2].to_numpy()
    fp_x = fp_df.iloc[:, :-2].to_numpy()

    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(14, 4))

    # Plot Ground Truth
    ax1.scatter(true_x_0[:, 0], true_x_0[:, 1], c='dodgerblue', s=size, alpha=0.6, label='Negative Cases')
    ax1.scatter(true_x_1[:, 0], true_x_1[:, 1], c='orange', s=size, alpha=0.6, label='Positive Cases')
    ax1.legend(markerscale=markersize, loc='best', frameon=True, facecolor='white', edgecolor='black')
    ax1.set_title('Ground Truth of Test Data', fontsize=12)
    # ax1.set_xlabel('Principal Component 1', fontsize=12)
    # ax1.set_ylabel('Principal Component 2', fontsize=12)
    ax1.grid(True)

    # Plot Predictions
    ax2.scatter(pred_x_0[:, 0], pred_x_0[:, 1], c='dodgerblue', s=size, alpha=0.6, label='Negative Cases')
    ax2.scatter(pred_x_1[:, 0], pred_x_1[:, 1], c='orange', s=size, alpha=0.6, label='Positive Cases')
    ax2.legend(markerscale=markersize, loc='best', frameon=True, facecolor='white', edgecolor='black')
    ax2.set_title('Prediction', fontsize=12)
    # ax2.set_xlabel('Principal Component 1', fontsize=12)
    # ax2.set_ylabel('Principal Component 2', fontsize=12)
    ax2.grid(True)

    # Plot Comparison
    ax3.scatter(correct_x_0[:, 0], correct_x_0[:, 1], c='dodgerblue', s=size, alpha=0.6, label='True Negative')
    ax3.scatter(correct_x_1[:, 0], correct_x_1[:, 1], c='orange', s=size, alpha=0.6, label='True Positive')
    ax3.scatter(fn_x[:, 0], fn_x[:, 1], c='limegreen', s=size, alpha=0.6, label='False Negative')
    ax3.scatter(fp_x[:, 0], fp_x[:, 1], c='red', s=size, alpha=0.6, label='False Positive')
    ax3.legend(markerscale=markersize, loc='best', frameon=True, facecolor='white', edgecolor='black')
    ax3.set_title('Comparison', fontsize=12)
    # ax3.set_xlabel('Principal Component 1', fontsize=12)
    # ax3.set_ylabel('Principal Component 2', fontsize=12)
    ax3.grid(True)

    plt.tight_layout()
    plt.show()

# Example usage:
pca_plot(X_test, y_test, y_pred, size=100, markersize=1)
